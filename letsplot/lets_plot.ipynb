# %%
from lets_plot import *
import pandas as pd

LetsPlot.setup_html()
# Out:
#             <div id="iqCOyN"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.0.1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("iqCOyN").appendChild(div);
#                     };
#                     var e = document.getElementById("iqCOyN");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
df_cat_result = pd.read_csv("./data/category_df.csv", index_col=0)

# %%
df_cat_result
# Out:
#               subdiscipline  count
# 0                   control    387
# 1          gastroenterology    372
# 2   immunology/rheumatology    329
# 3             endocrinology    299
# 4            hemostaseology    229
# 5                nephrology    203
# 6                 neurology    171
# 7               pulmonology    158
# 8              infectiology     88
# 9                  oncology     57
# 10              allergology     43
# 11               hepatology     37
# 12       syndromic disorder     29
# 13       metabolic disorder     24
# 14               hematology     20
# 15             unclassified     17
# 16               cardiology      9
# 17        pediatric_surgery      8
# 18             unproccessed      4
# 19              neonatology      1
# 20              dermatology      1

# %%
## anzahl category
from lets_plot import *
ggplot(df_cat_result) + geom_bar(aes(x="subdiscipline", y="count"), stat='identity')
# Out:
#    <div id="5TMD8C"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "__error_message":"Unsupported data structure: String"
# };
#            var plotContainer = document.getElementById("5TMD8C");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
